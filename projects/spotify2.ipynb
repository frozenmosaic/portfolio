# %%
from math import pi
import pandas as pd
import numpy as np
import requests
import base64
import json
import spotipy
import spotipy.util as util
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import time

# %%
# initialize and authorize SpotipyOAuth 

usn = 'h_vy'
cid = '24da2914fefb43e198bf76d87e121f9c'
csc = '79bc72fb858041078caac075f9c369dd'
rur = 'http://localhost'
scp = 'user-read-private'

oam = spotipy.oauth2.SpotifyOAuth(username=usn, scope=scp, client_id=cid, client_secret=csc, redirect_uri=rur)
spo = spotipy.Spotify(oauth_manager=oam)

# %%
# feature categories
cat = ['danceability', 'energy', 'norm_loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']

# %%
# tracks of Fav playlist
fav_tracks = spo.playlist_tracks('2LlQtAk2KbOAGqgPwOUn9J')

# %%
"""
build and return a DataFrame of Track IDs and Names of Playlist Tracks
:trackJson: JSON Response, or Python dict, of Playlist Tracks
"""
def getTrackDf(trackJson):
    tracks = []
    for i in fav_tracks['items']:
        track = []
        track.append(i['track']['id'])
        track.append(i['track']['name'])
        track.append(i['track']['artists'][0]['name'])
        tracks.append(track)
    df = pd.DataFrame(data=tracks, columns=['id', 'name', 'artist'])
    return df

"""
build and return a DataFrame of Features of Multiple Tracks that 
include all features, track names and track IDs
:trackDf: list of track IDs 
:trackJson: JSON Response/Python dict of Tracks
"""
def getFeatureDf(featuresJson):
    featureDf = pd.DataFrame(featuresJson).set_index('id')

    # drop irrelevant columns
    featureDf.drop(['type', 'uri','track_href','analysis_url'], axis=1, inplace=True)

    # rescaling loudness
    minx = -60
    maxx = 0
    featureDf.insert(loc=3, column='norm_loudness', value=(featureDf['loudness']-minx)/(maxx-minx))

    return featureDf

# %%
t0 = time.time()
trackDf = getTrackDf(fav_tracks)
print('run time: {:.2f}'.format(time.time()-t0))
#features = sp.audio_features(trackId)
# Out:
# run time: 0.00

# %%
ch_id = trackDf.id[trackDf.artist.str.contains('Chillies')].tolist()

# %%
ft_ch = spo.audio_features(ch_id)

# %%
ftdf_ch = getFeatureDf(ft_ch)
# Out:
# [0.531, 0.317, 0.8240999999999999, 0.026, 0.816, 1.2e-06, 0.113, 0.302]

# %%
"""
draw a Radar Graph of a track's features
:track: list of features of a track
:cat: list of feature categories
:ax: Axes object to plot
"""
def radarGraph(track, cat, ax):
    
    # list of categories
    n = len(track)
    
    # duplicate first value to close the plot
    track += track[:1]

    angles = [i / float(n) * 2 * pi for i in range(n)]
    angles += angles[:1]
    
    # Plot data
    ax.plot(angles, track, linewidth=1, linestyle='solid')

    # Fill area
    ax.fill(angles, track, 'b', alpha=0.1)
    
    # set gridlines and labels
    thetaticks = np.arange(0,360,45)
    ax.set_thetagrids(thetaticks, labels=cat, fontsize=10)
    ax.set_rlabel_position(135)
    
# initialize the radar graph for multiple track
nr, nc = 1, 2
fig, axes = plt.subplots(nrows=nr, ncols=nc, subplot_kw=dict(polar=True), figsize=(nr*10, nc*10))

# initialize indices for Axes list
if nr != 1: 
    l = [[x, y] for x in range(nr) for y in range(nc)]
else: l = [y for y in range(nc)]

# shorten category names
cat_sh = [c[:4] for c in cat]

# graph
for i, r in zip(l, enumerate(ftdf_ch[cat].itertuples())):
    radarGraph(list(r[1][1:]), cat_sh, axes[i])

plt.tight_layout()
plt.show()

# %%
ftdf_ch
# Out:
#                         danceability  energy  key  norm_loudness  loudness  \
# id
# 1lhdtLh7c6Y21O36qxCXxD         0.531   0.317    1       0.824100   -10.554
# 1dZV513THyfDUONv351KVI         0.621   0.654   11       0.854567    -8.726
#
#                         mode  speechiness  acousticness  instrumentalness  \
# id
# 1lhdtLh7c6Y21O36qxCXxD     1       0.0260       0.81600          0.000001
# 1dZV513THyfDUONv351KVI     1       0.0333       0.00342          0.000037
#
#                         liveness  valence    tempo  duration_ms  \
# id
# 1lhdtLh7c6Y21O36qxCXxD    0.1130    0.302  149.917       291651
# 1dZV513THyfDUONv351KVI    0.0707    0.184  123.984       330968
#
#                         time_signature
# id
# 1lhdtLh7c6Y21O36qxCXxD               3
# 1dZV513THyfDUONv351KVI               4

# %%
pd.merge(ftdf_ch, trackDf, left_on='id', right_on='id')
# Out:
#                        id  danceability  energy  key  norm_loudness  loudness  \
# 0  1lhdtLh7c6Y21O36qxCXxD         0.531   0.317    1       0.824100   -10.554
# 1  1dZV513THyfDUONv351KVI         0.621   0.654   11       0.854567    -8.726
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0260       0.81600          0.000001    0.1130    0.302
# 1     1       0.0333       0.00342          0.000037    0.0707    0.184
#
#      tempo  duration_ms  time_signature                    name    artist
# 0  149.917       291651               3           Và Thế Là Hết  Chillies
# 1  123.984       330968               4  Nếu Ngày Mai Không Đến  Chillies

# %%
trackDf
# Out:
#                         id                                     name  \
# 0   0830WmzxBqOp9C93j8m9sN  Sign Of The Times - Spotify Studios NYC
# 1   1lhdtLh7c6Y21O36qxCXxD                            Và Thế Là Hết
# 2   1zVhMuH7agsRe6XkljIY4U                                    human
# 3   69vToJ9BMbbLlFZo7k7A7B                       You Are The Reason
# 4   5A1w94uzc1kO1Zhe8WWxC3                               Right Back
# ..                     ...                                      ...
# 77  2RMZcxr8c4SxZd9o6gw2CS                         Tình Yêu Tôi Hát
# 78  4oIZ0rINU4XUsOp5zUWnju                                      5am
# 79  42rme4MN6ki6mXgl4yaZtV                          Tầng Thượng 102
# 80  6N0uDUUQRQd7lIIFU2aaEQ                                  Hold Me
# 81  7mFigNlS2dsKMhcmJyfpeg                                Only Then
#
#              artist
# 0              LANY
# 1          Chillies
# 2   Christina Perri
# 3       Calum Scott
# 4            Khalid
# ..              ...
# 77         Thùy Chi
# 78     Cá Hồi Hoang
# 79     Cá Hồi Hoang
# 80         Eric Nam
# 81          Roy Kim
#
# [82 rows x 3 columns]

# %%
ft_fav = spo.audio_features(trackDf.id.tolist())

# %%
featureDf = getFeatureDf(ft_fav)

# %%
ftdf = pd.merge(featureDf, trackDf, left_on='id', right_on='id')
ftdf.head()
# Out:
#                        id  danceability  energy  key  norm_loudness  loudness  \
# 0  0830WmzxBqOp9C93j8m9sN         0.619   0.394    5       0.837550    -9.747
# 1  1lhdtLh7c6Y21O36qxCXxD         0.531   0.317    1       0.824100   -10.554
# 2  1zVhMuH7agsRe6XkljIY4U         0.439   0.489    8       0.895233    -6.286
# 3  69vToJ9BMbbLlFZo7k7A7B         0.331   0.235   10       0.871667    -7.700
# 4  5A1w94uzc1kO1Zhe8WWxC3         0.788   0.427    5       0.834700    -9.918
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0444        0.0472          0.020000     0.100    0.123
# 1     1       0.0260        0.8160          0.000001     0.113    0.302
# 2     1       0.0368        0.1320          0.000643     0.114    0.253
# 3     1       0.0299        0.9180          0.000000     0.137    0.218
# 4     0       0.3080        0.0649          0.000036     0.171    0.605
#
#      tempo  duration_ms  time_signature  \
# 0  124.000       319750               4
# 1  149.917       291651               3
# 2  143.808       250707               4
# 3  171.232       204326               3
# 4   97.038       215227               4
#
#                                       name           artist
# 0  Sign Of The Times - Spotify Studios NYC             LANY
# 1                            Và Thế Là Hết         Chillies
# 2                                    human  Christina Perri
# 3                       You Are The Reason      Calum Scott
# 4                               Right Back           Khalid

# %%
sns.countplot(x='mode', data=ftdf)

# %%
sns.distplot(ftdf.energy, bins=10)

# %%
sns.distplot(ftdf.danceability, bins=10)

# %%
sns.distplot(ftdf.acousticness, bins=10)

# %%
sns.boxplot(y=ftdf.energy)

# %%
list(reduce(lambda x: 'Chillies' in x, ftdf.artist.tolist()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ea6bfb5f2cde> in <module>
# ----> 1 list(reduce(lambda x: 'Chillies' in x, ftdf.artist.tolist()))
#
# NameError: name 'reduce' is not defined
