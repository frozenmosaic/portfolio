# %% [markdown]
# # Stock & Portfolio Analysis
#
# Using Alpha Vantage API to pull real-time stock info
#
# For each stock, compute and visualize:
# 1. Return, monthly and annualized
# 2. Volatility, month and annualized
# 3. Max drawdown
# 4. VaR & CVaR at 95% confidence level

# %%
import pandas as pd
import kit as kit
import matplotlib.pyplot as plt
import numpy as np
#from alpha_vantage.timeseries import TimeSeries
#import yfinance as yf

from datetime import datetime

key = 'LU0LA7RMZ6XIO00P'

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
ts = TimeSeries(key, output_format='pandas')

# portfolio
p = ['AAL', 'AAPL', 'AXP', 'BAC', 'BND', 'CMCSA', 'CVS', 'DAL', 'DIS', 
     'MA', 'NKE', 'SPY', 'UNH', 'V', 'VB', 'VHT', 'VTV', 'XAR']

# cost-basis
cb = [57.28, 250.11, 77.01, 44.46, 256.23, 44.52, 74.15, 108.44, 144.22, 
      284.09, 96.20, 304.99, 219.76, 353.94, 337.55, 196.97, 241.48, 65.42]

# quantity
q = [4, 1.0053, 1, 2, 3.0059, 1.0048, 1, 2, 1, 1.0012, 1, 
     1.0048, 1, 2.0065, 2.0084, 1.0029, 2, 1.0055]

# %%
# pulling data using Alpha Vantage
data = {}
r0 = ts.get_monthly_adjusted(symbol=p[0])[0]
data[p[0]] = r0['5. adjusted close']
dates = r0.index

for i in range(1, len(p)):
    r = ts.get_monthly_adjusted(symbol=p[i])[0]
    n = r['5. adjusted close']
    data[p[i]] = n

prices = pd.DataFrame(data=data, index=dates)
prices.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-324-43747943581c> in <module>
#       6
#       7 for i in range(1, len(p)):
# ----> 8     r = ts.get_monthly_adjusted(symbol=p[i])[0]
#       9     n = r['5. adjusted close']
#      10     data[p[i]] = n
#
# /opt/anaconda3/lib/python3.7/site-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# /opt/anaconda3/lib/python3.7/site-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#     162
#
# /opt/anaconda3/lib/python3.7/site-packages/alpha_vantage/alphavantage.py in _handle_api_call(self, url)
#     339                 raise ValueError(json_response["Information"])
#     340             elif "Note" in json_response and self.treat_info_as_error:
# --> 341                 raise ValueError(json_response["Note"])
#     342             return json_response
#     343         else:
#
# ValueError: Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.

# %%
prices.head()
# Out:
#                 GS      AAPL        AXP        BAC       MSFT       UNH  \
# Date
# 1999-05  53.884857  1.366002  26.024323  15.254425  25.884752  6.127341
# 1999-06  57.305325  1.435755  27.972456  17.288345  28.932383  6.580487
# 1999-07  51.009659  1.726393  28.494200  15.877847  27.528864  6.409736
# 1999-08  47.440479  2.022845  29.737785  14.472472  29.694281  6.390033
# 1999-09  48.486591  1.962780  29.197115  13.321251  29.052683  5.115969
#
#                JPM       INTC
# Date
# 1999-05  25.823458  17.300385
# 1999-06  30.863255  19.049686
# 1999-07  27.495981  22.091236
# 1999-08  30.073553  26.313375
# 1999-09  27.086420  23.801895

# %%
t = yf.download(tickers='aapl', period='10y', interval='3mo').dropna()['Adj Close']
t
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2010-05-01     31.900509
# 2010-08-01     37.323280
# 2010-11-01     42.077667
# 2011-02-01     43.418163
# 2011-05-01     48.421799
# 2011-08-01     50.195084
# 2011-11-01     56.606174
# 2012-02-01     72.416931
# 2012-05-01     75.737808
# 2012-08-01     73.823158
# 2012-11-01     56.725925
# 2013-02-01     55.394901
# 2013-05-01     56.944649
# 2013-08-01     66.209930
# 2013-11-01     63.829231
# 2014-02-01     75.678955
# 2014-05-01     86.338547
# 2014-08-01     98.082008
# 2014-11-01    106.930092
# 2015-02-01    114.717735
# 2015-05-01    111.627487
# 2015-08-01    110.430367
# 2015-11-01     90.359383
# 2016-02-01     87.390038
# 2016-05-01     97.677963
# 2016-08-01    107.071121
# 2016-11-01    115.056038
# 2017-02-01    136.898727
# 2017-05-01    142.354492
# 2017-08-01    162.461700
# 2017-11-01    161.546280
# 2018-02-01    160.025726
# 2018-05-01    185.014206
# 2018-08-01    213.612686
# 2018-11-01    163.019196
# 2019-02-01    197.231476
# 2019-05-01    210.287552
# 2019-08-01    246.491638
# 2019-11-01    307.852936
# 2020-02-01    287.048767
# 2020-04-30    293.799988
# Name: Adj Close, dtype: float64

# %%
t1 = pd.DataFrame(columns=['AAPL'])
t1['AAPL'] = t.values

# %%
# pull data using yfinance bc of Alpha Vantage limits

prices = pd.DataFrame(columns=p)

for i in range(len(p)):
    prices[p[i]] = yf.download(tickers=p[i], period='10y', interval='3mo').dropna()['Adj Close']
    
prices.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   AAL       AAPL        AXP        BAC        BND      CMCSA  \
# Date
# 2010-05-01  10.228744  31.900509  38.441006  12.544461  61.338009   8.074250
# 2010-08-01  11.114922  37.323280  35.863628  10.236974  62.524616   8.601369
# 2010-11-01   9.351994  42.077667  37.701740  12.285292  61.244785   9.536109
# 2011-02-01   8.569520  43.418163  42.831059  10.997910  62.507927  11.034145
# 2011-05-01   5.882706  48.421799  43.842575   8.702476  64.040985  10.157708
#
#                   CVS        DAL        DIS         MA        NKE         SPY  \
# Date
# 2010-05-01  25.061472  10.553022  29.344988  17.943613  13.731149   90.124916
# 2010-08-01  24.675758  12.338504  31.470297  20.663555  15.413598   97.303963
# 2010-11-01  28.089453  10.366478  33.856922  20.495655  15.847722  106.237732
# 2011-02-01  29.854738   9.220567  37.952000  24.065033  16.043983  113.228470
# 2011-05-01  30.067553   7.008699  34.007111  26.603329  17.820192  107.802177
#
#                   UNH          V         VB        VHT        VTV  XAR
# Date
# 2010-05-01  25.994186  15.181141  52.280205  43.697258  36.724377  NaN
# 2010-08-01  30.903881  16.273340  56.899006  47.874916  38.850891  NaN
# 2010-11-01  35.319912  14.640408  63.025784  48.839638  42.883976  NaN
# 2011-02-01  42.497681  16.505848  70.870415  55.985775  45.962555  NaN
# 2011-05-01  42.966274  18.220211  65.567520  54.022903  42.811581  NaN

# %%
prices.drop('XAR',axis=1, inplace=True) # no data for XAR

# %%
# df of monthly stock return
mon_r = kit.rets_fr_prices(prices) 

# construct df of cumulative annualized return from monthly return
y = pd.to_datetime(np.arange(2010,2021,1), format='%Y').to_period('Y')
ann_r = pd.DataFrame(columns=mon_r.columns, index=y, dtype='float') 

for i in range(len(y)):
    ann_r.loc[str(y[i])] = ( 1+mon_r[str(y[i])] ).prod()-1

# covariance matrix
cov = mon_r.cov()

# %%
ann_r
# Out:
#            AAL      AAPL       AXP       BAC       BND     CMCSA       CVS  \
# 2010 -0.085833  0.318590 -0.019417 -0.020800 -0.001380  0.181085  0.120930
# 2011 -0.149634  0.345992  0.174809 -0.479179  0.086633  0.191700  0.237921
# 2012  0.692184  0.001770  0.188819  0.596291  0.025932  0.460292  0.244258
# 2013  1.347606  0.126016  0.464493  0.486022 -0.003585  0.456364  0.343128
# 2014  0.470170  0.675619 -0.040343 -0.090922  0.066448 -0.008186  0.478155
# 2015 -0.199501 -0.155378 -0.327654 -0.055423 -0.004079  0.064475 -0.002595
# 2016  0.147350  0.273759  0.455966  0.626583  0.016249  0.378012 -0.169582
# 2017  0.239152  0.403629  0.323001  0.435195  0.025099  0.145827  0.024317
# 2018 -0.335830  0.009574  0.048423 -0.095526  0.024561 -0.122444 -0.142420
# 2019 -0.240980  0.888133  0.283897  0.179460  0.098364  0.204894  0.069596
# 2020 -0.549712 -0.045632 -0.290435 -0.258457  0.037186 -0.119303 -0.079361
#
#            DAL       DIS        MA       NKE       SPY       UNH         V  \
# 2010 -0.018040  0.153472  0.142784  0.154444  0.179360  0.359027 -0.035200
# 2011 -0.096642  0.011291  0.536459  0.335791  0.040913  0.277665  0.484995
# 2012  0.315813  0.409404  0.502845  0.099730  0.165253  0.081752  0.619056
# 2013  1.212130  0.368921  0.515142  0.400127  0.215740  0.335831  0.410330
# 2014  0.559005  0.266914  0.103797  0.306161  0.141648  0.494246  0.219986
# 2015 -0.054752  0.071913  0.093658  0.374496 -0.009734  0.099781  0.190900
# 2016  0.081383  0.171015  0.203869 -0.133261  0.199727  0.431168  0.121273
# 2017  0.225225 -0.003147  0.601175  0.306462  0.264758  0.484792  0.513526
# 2018 -0.107035  0.042772  0.256485  0.214125 -0.025172  0.157217  0.094687
# 2019  0.166374  0.258105  0.504306  0.189167  0.216705  0.023325  0.482082
# 2020 -0.532050 -0.214192 -0.127071 -0.089419 -0.086748  0.082260 -0.098725
#
#             VB       VHT       VTV
# 2010  0.205504  0.117920  0.168032
# 2011  0.030211  0.144016  0.016071
# 2012  0.169732  0.231064  0.182574
# 2013  0.274865  0.356921  0.206932
# 2014  0.074071  0.253158  0.127553
# 2015 -0.083199 -0.037919 -0.018728
# 2016  0.300611  0.095100  0.235096
# 2017  0.178420  0.282439  0.222851
# 2018 -0.014187  0.048316 -0.035309
# 2019  0.117528  0.120622  0.144301
# 2020 -0.177944  0.014900 -0.143284

# %%
ann_r.index
# Out:
# PeriodIndex(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#              '2018', '2019', '2020'],
#             dtype='period[A-DEC]', freq='A-DEC')

# %%
# line chart of time series of each stock return in past 10 years
plt.figure(figsize=(15,7))

for i in range(len(p)):
    plt.plot(ann_r.index.to_timestamp(), ann_r[p[i]], label=p[i], marker='.')

plt.legend()
plt.show()

# %%
# Sharpe Ratios of each stock
ratios = kit.sharpe_ratio(mon_r, 0.03, 12).sort_values(ascending=False)

plt.figure(figsize=(10,5))
plt.bar(ratios.index, ratios.values)
plt.show()

# %%
# Max Drawdowns of each stock
plt.figure()

for i in range(5):
    dd = kit.drawdown(mon_r[p[i]])['Drawdowns']
    plt.plot(dd, label=p[i])

plt.legend()
plt.show()

# %%
# AAPL
aapl = pd.read_csv('data/AAPL.csv', header=0)
aapl.drop(columns=['Open', 'Close', 'High', 'Low', 'Volume'], inplace=True)
aapl.Date = pd.to_datetime(aapl.Date).dt.to_period('M')
aapl.set_index('Date', inplace=True)
aapl.head()
# Out:
#          Adj Close
# Date
# 1980-12   0.481528
# 1981-01   0.398628
# 1981-02   0.373934
# 1981-03   0.345713
# 1981-04   0.400392

# %%
# time series of monthly return
m_ret = kit.rets_fr_prices(aapl)
m_ret.plot(figsize=(10,5))

# %%
# annual return
compounded_growth = (1+m_ret).prod() # monthly
n_periods = m_ret.shape[0] # total number of data periods
compounded_growth**(12/n_periods)-1
# Out:
# Adj Close    0.181111
# dtype: float64

# %%
# annual volatility
m_ret.std()*(12**0.5)
# Out:
# Adj Close    0.452644
# dtype: float64

# %%
# max drawdown
dd = kit.drawdown(m_ret['Adj Close'])
dd.Drawdowns.plot()

# %%
dd.Wealth.plot()

# %% [markdown]
# ## Semidev, VaR, CVaR
#
# ### Interpreting VaR
# "Let's say we have a $10 million portfolio, which has a 4.3% VaR at a 5% probability level for one month. What does that value at risk number mean?
#
# What we're saying is that over the next month there's a 5% probability that the portfolio could lose more than 4.3% of its value. Put differently, we are also saying that there's a 95% chance that the portfolio will lose less than 4.3%."
# source: https://gostudy.io/blog/understanding-and-interpreting-var

# %%
kit.var_gaussian(rets).sort_values(ascending=False)
# Out:
# BAC     0.181605
# AAPL    0.163022
# INTC    0.150126
# GS      0.144853
# AXP     0.140502
# JPM     0.136062
# MSFT    0.128136
# UNH     0.098755
# dtype: float64

# %% [markdown]
# # **Portfolio Analysis**
#
# Given weights, calculate:
# 1. Return
# 2. Volatility and covariance matrix
# 3. Sharpe Ratio
# 4. Max drawdown
#
# Test out portfolio ideas:
# 1. Max Sharpe
# 2. Global Minimum Variance
# 3. Equal Weight
# 4. Industry-skewed
# 5. Value and small-cap

# %% [markdown]
# ## Given weights, calculate portfolio effectiveness

# %%
# calculate portfolio distribution, capitalization and weights based on cost basis and quantity
p_dist = prices.tail(1) * q[:-1]
p_cap = p_dist.sum(axis=1)
p_weights = (p_dist / p_cap[0]).iloc[0]

# %%
# calculate portfolio return and volatility
ann_r_s = kit.ann_rets(mon_r, 4) # ann_r_s = annualized return of each stock, single value
p_ret = kit.portfolio_return(p_weights, ann_r_s)
p_vol = kit.portfolio_vol(p_weights, cov)

# %%
p_ret
# Out:
# 0.1675768844355375

# %%
p_vol
# Out:
# 0.046690575185992025

# %%
cov
# Out:
#             AAL      AAPL       AXP       BAC       BND     CMCSA       CVS  \
# AAL    0.035603  0.000975  0.005329  0.011700 -0.000484  0.008263  0.005069
# AAPL   0.000975  0.013724  0.003887 -0.000518  0.000145  0.002402  0.000751
# AXP    0.005329  0.003887  0.010076  0.006927 -0.000261  0.004227  0.000534
# BAC    0.011700 -0.000518  0.006927  0.020817 -0.001358  0.007215  0.001929
# BND   -0.000484  0.000145 -0.000261 -0.001358  0.000253 -0.000267 -0.000119
# CMCSA  0.008263  0.002402  0.004227  0.007215 -0.000267  0.010057  0.002779
# CVS    0.005069  0.000751  0.000534  0.001929 -0.000119  0.002779  0.008406
# DAL    0.022829  0.001287  0.006889  0.009038 -0.000800  0.005018  0.003223
# DIS    0.007482  0.003164  0.005624  0.006704 -0.000407  0.007087  0.002466
# MA     0.003181  0.003030  0.005516  0.002774 -0.000065  0.002060 -0.000430
# NKE    0.003731  0.000182  0.002252  0.002366 -0.000185  0.002408  0.002473
# SPY    0.003623  0.001968  0.003079  0.003905 -0.000153  0.003272  0.000989
# UNH    0.001247  0.000751  0.001562  0.003382 -0.000220  0.002262  0.002549
# V      0.004630  0.002254  0.003696  0.002448  0.000060  0.002454  0.000548
# VB     0.004579  0.001511  0.004416  0.005683 -0.000290  0.004114  0.000966
# VHT    0.002746  0.000909  0.002017  0.002560  0.000044  0.003288  0.002399
# VTV    0.004549  0.001439  0.003375  0.004687 -0.000250  0.003573  0.001347
#
#             DAL       DIS        MA       NKE       SPY       UNH         V  \
# AAL    0.022829  0.007482  0.003181  0.003731  0.003623  0.001247  0.004630
# AAPL   0.001287  0.003164  0.003030  0.000182  0.001968  0.000751  0.002254
# AXP    0.006889  0.005624  0.005516  0.002252  0.003079  0.001562  0.003696
# BAC    0.009038  0.006704  0.002774  0.002366  0.003905  0.003382  0.002448
# BND   -0.000800 -0.000407 -0.000065 -0.000185 -0.000153 -0.000220  0.000060
# CMCSA  0.005018  0.007087  0.002060  0.002408  0.003272  0.002262  0.002454
# CVS    0.003223  0.002466 -0.000430  0.002473  0.000989  0.002549  0.000548
# DAL    0.026949  0.007851  0.005287  0.007199  0.003957  0.000133  0.005317
# DIS    0.007851  0.010262  0.003011  0.003397  0.003428  0.001052  0.002955
# MA     0.005287  0.003011  0.006799  0.003550  0.001939  0.000520  0.004882
# NKE    0.007199  0.003397  0.003550  0.008735  0.001819  0.000609  0.003032
# SPY    0.003957  0.003428  0.001939  0.001819  0.002205  0.001536  0.001278
# UNH    0.000133  0.001052  0.000520  0.000609  0.001536  0.005988 -0.000164
# V      0.005317  0.002955  0.004882  0.003032  0.001278 -0.000164  0.005168
# VB     0.005079  0.004570  0.002579  0.001880  0.002806  0.002489  0.001500
# VHT    0.001967  0.002994  0.001358  0.001771  0.001761  0.002859  0.001344
# VTV    0.004653  0.003743  0.001717  0.001595  0.002328  0.001711  0.001019
#
#              VB       VHT       VTV
# AAL    0.004579  0.002746  0.004549
# AAPL   0.001511  0.000909  0.001439
# AXP    0.004416  0.002017  0.003375
# BAC    0.005683  0.002560  0.004687
# BND   -0.000290  0.000044 -0.000250
# CMCSA  0.004114  0.003288  0.003573
# CVS    0.000966  0.002399  0.001347
# DAL    0.005079  0.001967  0.004653
# DIS    0.004570  0.002994  0.003743
# MA     0.002579  0.001358  0.001717
# NKE    0.001880  0.001771  0.001595
# SPY    0.002806  0.001761  0.002328
# UNH    0.002489  0.002859  0.001711
# V      0.001500  0.001344  0.001019
# VB     0.004193  0.002428  0.003115
# VHT    0.002428  0.003126  0.001762
# VTV    0.003115  0.001762  0.002654

# %%
ax = kit.plot_ef(25, ann_r_s, cov, riskfree_rate=0.02, show_ew=True, show_gmv=True)
plt.figure(figsize=(10,5))

# %%
# minimal volatility weights to yield same current return
mv_weights = kit.minimize_vol(p_ret, ann_r_s, cov, p[:-1])
mv_weights
# Out:
#               w
# AAL    0.000000
# AAPL   0.027380
# AXP    0.000000
# BAC    0.000000
# BND    0.417932
# CMCSA  0.000000
# CVS    0.000000
# DAL    0.000000
# DIS    0.000000
# MA     0.060398
# NKE    0.009863
# SPY    0.000000
# UNH    0.261185
# V      0.223241
# VB     0.000000
# VHT    0.000000
# VTV    0.000000

# %%
# max Sharpe Ratio
msr_weights = kit.msr(0.02,ann_r_s,cov,p[:-1])
msr_weights
# Out:
#               w
# AAL    0.000000
# AAPL   0.023962
# AXP    0.000000
# BAC    0.000000
# BND    0.490779
# CMCSA  0.000000
# CVS    0.000000
# DAL    0.000000
# DIS    0.000000
# MA     0.055280
# NKE    0.013047
# SPY    0.000000
# UNH    0.229655
# V      0.187277
# VB     0.000000
# VHT    0.000000
# VTV    0.000000

# %%
# Global Minimum Var portfolio
gmv_weights = kit.gmv(cov, p[:-1])
gmv_weights
# Out:
#               w
# AAL    0.000000
# AAPL   0.000140
# AXP    0.000000
# BAC    0.056048
# BND    0.899962
# CMCSA  0.000000
# CVS    0.003040
# DAL    0.010151
# DIS    0.000000
# MA     0.000000
# NKE    0.008808
# SPY    0.000000
# UNH    0.021850
# V      0.000000
# VB     0.000000
# VHT    0.000000
# VTV    0.000000
